# %%
import pandas as pd

vec = pd.read_csv("embedded_data_check.csv" ,encoding="utf-8-sig")

id = pd.read_csv("SQL_DB.csv",encoding="utf-8-sig")

# %%
id = id[["id","name"]]

# %%
vec.head(1)
# Out:
#    id                   embedded  \
# 0   1  음식이 맛있고 알바생이 매우 친절하고 귀여워요
#
#                                            embedding
# 0  [0.030689973384141922, -0.02415662817656994, -...

# %%
merged_df = vec.merge(id, on="id", how="left")

# %%
merged_df.to_csv("embedded_withname.csv",encoding="utf-8-sig",index=False)
